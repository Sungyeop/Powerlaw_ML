# %% [markdown]
# # Power Laws in Self-Supervised Learning

# %%
from IPython.display import Image

# %%
Image("Self_supervised.png", width=1000)

# %%
import Self_supervised
Self_supervised.main()
# Out:
# Training Starts!
# (Regression model(X-Z1-Z2-Z3-Y), Data : MNIST, Activation : Sigmoid)
# [1 epoch]
# [2 epoch]
# [3 epoch]
# [4 epoch]
# [5 epoch]
# [6 epoch]
# [7 epoch]
# [8 epoch]
# [9 epoch]
# [10 epoch]
# Training Ends!
# Visualizing the cluster frequency of the hidden layer...
