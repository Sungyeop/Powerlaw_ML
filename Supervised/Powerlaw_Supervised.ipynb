# %% [markdown]
# # Power Laws in Supervised Learning

# %%
from IPython.display import Image

# %%
Image("Supervised.png", width=1000)

# %%
import Supervised
Supervised.main()
# Out:
# Training Starts!
# (Classification model(X-Z1-Z2-Z3-Y), Data : MNIST, Activation : Sigmoid)
# [1 epoch] Train accuracy: 94.31%, Test accuracy: 93.65%
# [2 epoch] Train accuracy: 96.40%, Test accuracy: 95.37%
# [3 epoch] Train accuracy: 97.59%, Test accuracy: 96.32%
# [4 epoch] Train accuracy: 97.67%, Test accuracy: 96.19%
# [5 epoch] Train accuracy: 98.33%, Test accuracy: 96.60%
# [6 epoch] Train accuracy: 98.00%, Test accuracy: 96.22%
# [7 epoch] Train accuracy: 98.13%, Test accuracy: 96.22%
# [8 epoch] Train accuracy: 98.92%, Test accuracy: 96.72%
# [9 epoch] Train accuracy: 99.12%, Test accuracy: 96.80%
# [10 epoch] Train accuracy: 98.95%, Test accuracy: 96.73%
# Training Ends!
# Visualizing the cluster frequency of the hidden layer...
