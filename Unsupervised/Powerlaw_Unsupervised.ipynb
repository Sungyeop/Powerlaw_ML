# %% [markdown]
# # Power Laws in Unsupervised Learning

# %%
from IPython.display import Image

# %%
Image("Unsupervised.png", width=1000)

# %%
import Unsupervised
Unsupervised.main()
# Out:
# Training Starts!
# (Energy based model(X-Z), Data : MNIST)
# [Epoch 1]
# [Epoch 2]
# [Epoch 3]
# [Epoch 4]
# [Epoch 5]
# [Epoch 6]
# [Epoch 7]
# [Epoch 8]
# [Epoch 9]
# [Epoch 10]
# Training Ends!
# Visualizing the cluster frequency of the hidden layer...
